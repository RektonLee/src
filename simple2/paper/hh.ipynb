# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import roc_curve, auc, precision_recall_curve

# === 读取 CSV 文件 ===
df = pd.read_csv("val_pred_results.csv")  # 改成你的文件名
errors = df['kcatErr'].values

# === Ground Truth：是否低于50%误差 ===
threshold = 50.0
y_true = (errors < threshold).astype(int)

# === 置信得分：误差越小越可靠（取负值） ===
y_scores = -errors

# === ROC 曲线 ===
fpr, tpr, _ = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='AUC = %.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("roc_curve.png", dpi=300)
plt.show()

# === PR 曲线 ===
precision, recall, _ = precision_recall_curve(y_true, y_scores)

plt.figure(figsize=(6,5))
plt.plot(recall, precision, color='green', lw=2)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.tight_layout()
plt.savefig("pr_curve.png", dpi=300)
plt.show()

# === 误差分布图 ===
plt.figure(figsize=(7,5))
sns.histplot(errors, kde=True, bins=30, color='skyblue')
plt.axvline(x=threshold, color='red', linestyle='--', label='Threshold = 50%')
plt.xlabel("kcat Error (%)")
plt.ylabel("Count")
plt.title("Distribution of kcat Prediction Error")
plt.legend()
plt.tight_layout()
plt.savefig("error_distribution.png", dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 13
#      11 # === Ground Truth：是否低于50%误差 ===
#      12 threshold = 50.0
# ---> 13 y_true = (errors < threshold).astype(int)
#      15 # === 置信得分：误差越小越可靠（取负值） ===
#      16 y_scores = -errors
#
# TypeError: '<' not supported between instances of 'str' and 'float'
